# %%
import pandas as pd
# 깃허브의 엑셀파일로 데이터 프레임 부르기
url = 'https://github.com/panda-kim/excel/blob/main/student_relplot.xlsx?raw=True'
df = pd.read_excel(url)
df
# Out:
#      gender  age  height  weight
# 0    female   14   153.0    45.0
# 1    female   14   164.6    52.0
# 2    female   16   158.0    52.0
# 3      male   15   170.0    54.0
# 4      male   14   171.0    58.0
# ..      ...  ...     ...     ...
# 495  female   15   159.0    42.0
# 496    male   13   167.0    52.0
# 497    male   16   175.0    63.0
# 498  female   12   158.0    49.0
# 499  female   16   153.7    44.8
#
# [500 rows x 4 columns]

# %%
import seaborn as sns
# seaborn 테마 설정
sns.set_theme(style="whitegrid")

sns.relplot(x="height", y="weight", hue="gender", size="age",
            sizes=(40, 200), alpha=.8, palette='RdBu', data=df, height=8)
