# %%
import pandas as pd
pd.options.display.max_rows = 6 # 6행까지만 출력
url1 = 'https://github.com/panda-kim/csv_files/blob/main/std_hw.csv?raw=true'
df = pd.read_csv(url1)
df
# Out:
#      gender  age  height  weight
# 0    female   14   153.0    45.0
# 1    female   14   164.6    52.0
# 2    female   16   158.0    52.0
# ..      ...  ...     ...     ...
# 997  female   15   165.2    53.0
# 998    male   13   165.0    47.0
# 999    male   15   179.7    67.9
#
# [1000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  1000 non-null   object
#  1   age     1000 non-null   int64
#  2   height  1000 non-null   float64
#  3   weight  1000 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 31.4+ KB

# %%
# 15세 이하이면서 키가 170 이상인 학생의 데이터만 추출
df[(df['age'] <= 15) and (df['height'] >= 170)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-edd077320ab2> in <cell line: 2>()
#       1 # 15세 이하이면서 키가 170 이상인 학생의 데이터만 추출
# ----> 2 df[(df['age'] <= 15) and (df['height'] >= 170)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
